# %% [markdown]
# # Dia 2 Libreta 6
# En esta libreta usaremos un clasificador para detectar rostros en imagenes; despues realizaran el ejercicio de tomar una foto de su rostro con el dispositivo, extraerlo del mismo a la maquina y aplciar el detector.
#
# Finalmente, trataremos de implementarlo en el dispositivo...
#
# Algo de informacion [tomada de este sitio](https://realpython.com/blog/python/face-recognition-with-python/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, re, time
import numpy as np
import cv2

# %%
pic = os.path.join('.','ZuzanaB.jpg')

# %%
img=cv2.imread(pic)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
caras = caras_cascada.detectMultiScale(gray, 1.2, 2)

# %%
print "Encontramos {0} faces!".format(len(caras))
# Out:
# Encontramos 2 faces!

# %%
caras
# Out:
# array([[232, 330, 124, 124],
#        [216, 126, 225, 225]])

# %%
for (x,y,w,h) in caras:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(img)

# %% [markdown]
# Mi ejercicio

# %%
caras = caras_cascada.detectMultiScale(gray, 1.2, 3)
print "Encontramos {0} faces!".format(len(caras))
i= img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)
plt.imshow(i)
# Out:
# Encontramos 1 faces!

# %% [markdown]
# ************************* Termina mi ejercicio

# %%
import android
droide=android.Android()

# %%
droide.ttsSpeak("Hola listo para el registro")
# Out:
# Result(id=0, result=None, error=None)

# %%
droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')
# Out:
# Result(id=1, result={u'takePicture': True, u'autoFocus': True, u'cameraId': 0}, error=None)

# %%
# !adb pull /sdcard/DCIM/carota.jpg
# Out:
# 2273 KB/s (60541 bytes in 0.026s)

# %%
droide.getLaunchableApplications().result
# Out:
# {u'Alerta': u'com.motorola.bodyguard.app.DashboardActivity',
#  u'Assist': u'com.motorola.contextaware.ui.GalleryActivity',
#  u'Ayuda': u'com.motorola.genie.app.DashboardActivity',
#  u'Barcode Scanner': u'com.google.zxing.client.android.CaptureActivity',
#  u'BuildingCameraApp': u'mx.lania.buildingcameraapp.BuildCameraApp',
#  u'B\xfasqueda por voz': u'com.google.android.googlequicksearchbox.VoiceSearchActivity',
#  u'Calculadora': u'com.android.calculator2.Calculator',
#  u'Calendario': u'com.android.calendar.AllInOneActivity',
#  u'Chrome': u'com.google.android.apps.chrome.Main',
#  u'ColorNote': u'com.socialnmobile.colornote.activity.Main',
#  u'Config. de Google': u'com.google.android.gms.app.settings.GoogleSettingsActivity',
#  u'Configurar': u'com.android.settings.Settings',
#  u'Contactos': u'com.android.contacts.activities.PeopleActivity',
#  u'Correo': u'com.android.email.activity.Welcome',
#  u'C\xe1mara': u'com.motorola.camera.Camera',
# ...

# %% [markdown]
# Mi ejercicio

# %%
import android
droide=android.Android()
droide.ttsSpeak("Hola listo para la foto")
droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/anny.jpg')
droide.ttsSpeak("termino la foto")
# !adb pull /sdcard/DCIM/CAMERA/IMG_20140914_114006176.jpg

pic = os.path.join('.','IMG_20140914_114006176.jpg')
img=cv2.imread(pic)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
caras = caras_cascada.detectMultiScale(gray, 1.3, 6)
print "Encontramos {0} faces!".format(len(caras))
i= img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)
plt.imshow(i)
# Out:
# Encontramos 3 faces!
# 3289 KB/s (859029 bytes in 0.255s)

# %% [markdown]
# Termina mi ejercicio

# %%
# !adb pull /sdcard/DCIM/CAMERA/IMG_20150915_134306650_HDR.jpg
pic = os.path.join('.','IMG_20150915_134306650_HDR.jpg')
img=cv2.imread(pic)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
caras = caras_cascada.detectMultiScale(gray, 1.6, 2)
print "Encontramos {0} faces!".format(len(caras))
i= img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)
plt.imshow(i)
# Out:
# Encontramos 1 faces!
# 4078 KB/s (1202764 bytes in 0.288s)
